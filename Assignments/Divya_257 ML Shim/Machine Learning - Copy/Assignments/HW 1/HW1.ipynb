# %% [markdown]
# # Hands on Lab & Homework

# %% [markdown]
# ### Q1. Perform the following computation without use of any libraries
#
#
# ```math
#     [1,-40,36]
# A = [2,80,-72]
#     [3,-40,-72]
#
#     [0,49,7]
# B = [9,64,81]
#     [222,3,0.1]
# ```
#
# Given two matrices A & B perform the operations:
# * A + B
# * A - B
# * AB

# %%
A = [[1,-40,36],[2,80,-72],[3,-40,-72]]
B = [[0,49,7],[9,64,81],[222,3,0.1]]
A_add_B = []

for i in range(len(A)):
    temp = []
    for j in range(len(B)):
        temp.append(A[i][j] + B[i][j])
    A_add_B.append(temp)
        
print("A+B = ", A_add_B)

A_sub_B = []

for i in range(len(A)):
    temp = []
    for j in range(len(B)):
        temp.append(A[i][j] - B[i][j])
    A_sub_B.append(temp)
        
print("A-B = ", A_sub_B)

A_mul_B = []
for i in range(len(A)):
    temp = []
    temp_sum = 0
    for j in range(len(A[0])):
        for k in range(len(B)):
            temp_sum = temp_sum + (A[i][k] * B[k][j])
        temp.append(temp_sum)
        temp_sum = 0
    A_mul_B.append(temp)
        
print("AB = ", A_mul_B)
# Out:
# A+B =  [[1, 9, 43], [11, 144, 9], [225, -37, -71.9]]
# A-B =  [[1, -89, 29], [-7, 16, -153], [-219, -43, -72.1]]
# AB =  [[7632, -2403, -3229.4], [-15264, 5002, 6486.8], [-16344, -2629, -3226.2]]

# %% [markdown]
# ### Q2. Perform the same computation using Numpy package

# %%
import numpy 

A = numpy.array([[1,-40,36],[2,80,-72],[3,-40,-72]])
B = numpy.array([[0,49,7],[9,64,81],[222,3,0.1]])

A_add_B = numpy.add(A,B)
print("A+B = ", A_add_B)

A_sub_B = numpy.subtract(A,B)
print("A-B = ", A_sub_B)

A_mul_B = numpy.dot(A,B)
print("AB = ", A_mul_B)
# Out:
# A+B =  [[  1.    9.   43. ]
#  [ 11.  144.    9. ]
#  [225.  -37.  -71.9]]
# A-B =  [[   1.   -89.    29. ]
#  [  -7.    16.  -153. ]
#  [-219.   -43.   -72.1]]
# AB =  [[  7632.   -2403.   -3229.4]
#  [-15264.    5002.    6486.8]
#  [-16344.   -2629.   -3226.2]]

# %% [markdown]
# ### Q3. Compute using numpy
# * A<sup>T</sup>
# * B<sup>T</sup>
# * A<sup>T</sup>B<sup>T</sup>
# * AA<sup>T</sup>

# %%
print("A transpose = ", A.T)
print("B transpose = ", B.transpose())

A_trans = numpy.transpose(A)
B_trans = numpy.transpose(B)
print("ATBT = ", numpy.dot(A_trans,B_trans))
print("AAT = ", numpy.dot(A,A_trans))
# Out:
# A transpose =  [[  1   2   3]
#  [-40  80 -40]
#  [ 36 -72 -72]]
# B transpose =  [[0.00e+00 9.00e+00 2.22e+02]
#  [4.90e+01 6.40e+01 3.00e+00]
#  [7.00e+00 8.10e+01 1.00e-01]]
# ATBT =  [[   119.     380.     228.3]
#  [  3640.    1520.   -8644. ]
#  [ -4032.  -10116.    7768.8]]
# AAT =  [[ 2897 -5790  -989]
#  [-5790 11588  1990]
#  [ -989  1990  6793]]

# %% [markdown]
# ### Q4. Load a dataset from file (data_1.csv)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("data_1.csv", header=None)

# %%
data.head(10)
# Out:
#           0         1
# 0 -0.752400 -1.992827
# 1 -0.702025 -1.935445
# 2  0.058185 -1.020321
# 3 -0.097662 -1.857889
# 4 -0.369050  0.209050
# 5  0.028525  0.131720
# 6  1.560481  4.002697
# 7 -0.345951 -2.628387
# 8 -0.104637 -1.392553
# 9 -0.450271 -3.526068

# %% [markdown]
# ### Q5. Print size of the matrix

# %%
print(data.shape)
# Out:
# (10000, 2)

# %%
print(np.shape(data))
# Out:
# (10000, 2)

# %%
print(data.size)
# Out:
# 20000

# %% [markdown]
# ### Q6. Slice matrix into X value & Y Value
#
# "Different ways to do slicing explain which you used and why?"

# %%
#X=data.values[:,0]
X1 = data.iloc[:,0]  #.iloc is used for integer based slicing, 
                     #the data which is provided to us has no labels hence .iloc is best to use in this case
print(X1)
Y1 = data.iloc[:,1]
print(Y1)
# Out:
# 0      -0.752400
# 1      -0.702025
# 2       0.058185
# 3      -0.097662
# 4      -0.369050
# 5       0.028525
# 6       1.560481
# 7      -0.345951
# 8      -0.104637
# 9      -0.450271
# 10      0.748953
# 11     -0.808008
# 12     -0.057437
# 13      0.259944
# 14     -1.863405
# 15      0.740556
# 16     -0.218435
# 17      0.485904
# 18      0.638871
# 19      0.617374
# 20      1.112827
# 21      0.381628
# 22     -1.451305
# 23     -0.071462
# 24      0.452624
# 25     -0.483214
# 26     -0.058265
# 27     -0.939526
# 28     -2.042370
# 29     -0.263867
#           ...
# 9970   -0.717376
# 9971   -0.047112
# 9972    1.162519
# 9973   -1.274710
# 9974   -0.239561
# 9975    0.727898
# 9976   -0.418480
# 9977   -0.218846
# 9978   -0.142819
# 9979   -0.669662
# 9980    0.835957
# 9981    1.512462
# 9982   -1.410654
# 9983    0.219617
# 9984    1.206325
# 9985    0.200156
# 9986   -0.984906
# 9987    0.022276
# 9988    1.462496
# 9989   -0.458328
# 9990    0.167128
# ...

# %%
X = data.loc[:,0]  # .loc is mainly used when data is labeled but can also be used with position based indexing
print(X)
Y = data.loc[:,1]
print(Y)
# Out:
# 0      -0.752400
# 1      -0.702025
# 2       0.058185
# 3      -0.097662
# 4      -0.369050
# 5       0.028525
# 6       1.560481
# 7      -0.345951
# 8      -0.104637
# 9      -0.450271
# 10      0.748953
# 11     -0.808008
# 12     -0.057437
# 13      0.259944
# 14     -1.863405
# 15      0.740556
# 16     -0.218435
# 17      0.485904
# 18      0.638871
# 19      0.617374
# 20      1.112827
# 21      0.381628
# 22     -1.451305
# 23     -0.071462
# 24      0.452624
# 25     -0.483214
# 26     -0.058265
# 27     -0.939526
# 28     -2.042370
# 29     -0.263867
#           ...
# 9970   -0.717376
# 9971   -0.047112
# 9972    1.162519
# 9973   -1.274710
# 9974   -0.239561
# 9975    0.727898
# 9976   -0.418480
# 9977   -0.218846
# 9978   -0.142819
# 9979   -0.669662
# 9980    0.835957
# 9981    1.512462
# 9982   -1.410654
# 9983    0.219617
# 9984    1.206325
# 9985    0.200156
# 9986   -0.984906
# 9987    0.022276
# 9988    1.462496
# 9989   -0.458328
# 9990    0.167128
# ...

# %%
X = data.iat[99,0]  # returns only one value present at specified index (integer based)
print(X)
Y = data.iat[99,1]
print(Y)
# Out:
# 1.924355692969093
# 5.346718905278639

# %%
X = data.at[99,0]  # to get a single value present at mentioned label. .at provides both label based and integer based lookups
print(X)
Y = data.at[99,1]
print(Y)
# Out:
# 1.924355692969093
# 5.346718905278639

# %% [markdown]
# ### Q7. Plot the data points

# %%
plt.scatter(X1,Y1)

# %%
plt.plot(X1,Y1)
plt.xlabel("X")
plt.ylabel("Y")
#plt.title("Relation between X and Y")
# Out:
# Text(0, 0.5, 'Y')

# %% [markdown]
# ### Q8. Plot a straight line that represents the relation between X & Y

# %%
sns.lmplot(x="0", y="1",data=data.rename(columns=lambda x:str(x)), scatter=False)

# %%
sns.lmplot(x="0", y="1",data=data.rename(columns=lambda x:str(x)))

# %% [markdown]
# ### Q9. Repeat Q4 - Q8 using data_2.csv

# %%
data2 = pd.read_csv("data_2.csv", header=None)
data2.head()
# Out:
#           0         1
# 0 -6.283185  0.043487
# 1 -6.281929  0.084347
# 2 -6.280672 -0.028693
# 3 -6.279415  0.021445
# 4 -6.278158  0.020871

# %%
print(data2.shape)
# Out:
# (10000, 2)

# %%
print(data2.size)
# Out:
# 20000

# %%
X2 = data2.iloc[:,0]
print(X2)
Y2 = data2.iloc[:,1]
print(Y2)
# Out:
# 0      -6.283185
# 1      -6.281929
# 2      -6.280672
# 3      -6.279415
# 4      -6.278158
# 5      -6.276901
# 6      -6.275645
# 7      -6.274388
# 8      -6.273131
# 9      -6.271874
# 10     -6.270618
# 11     -6.269361
# 12     -6.268104
# 13     -6.266847
# 14     -6.265591
# 15     -6.264334
# 16     -6.263077
# 17     -6.261820
# 18     -6.260564
# 19     -6.259307
# 20     -6.258050
# 21     -6.256793
# 22     -6.255537
# 23     -6.254280
# 24     -6.253023
# 25     -6.251766
# 26     -6.250509
# 27     -6.249253
# 28     -6.247996
# 29     -6.246739
#           ...
# 9970    6.246739
# 9971    6.247996
# 9972    6.249253
# 9973    6.250509
# 9974    6.251766
# 9975    6.253023
# 9976    6.254280
# 9977    6.255537
# 9978    6.256793
# 9979    6.258050
# 9980    6.259307
# 9981    6.260564
# 9982    6.261820
# 9983    6.263077
# 9984    6.264334
# 9985    6.265591
# 9986    6.266847
# 9987    6.268104
# 9988    6.269361
# 9989    6.270618
# 9990    6.271874
# ...

# %%
plt.figure(figsize=(8,8))
plt.scatter(X2,Y2)

# %%
sns.lmplot(x="0", y="1",data=data2.rename(columns=lambda x:str(x)), scatter=False)

# %%
sns.lmplot(x="0", y="1",data=data2.rename(columns=lambda x:str(x)))

# %% [markdown]
# ### Q10. Use Seaborn "TIPS" dataset and plot pairplot, jointplot, catplot, displot, and HeatMap
#
# "Comments on the different plots you used and why you used them what observations you made. Regarding the Heatmap, comment on observations you can make with a heat map and do you see any correlation in the data in consideration, which normalisation technique you used."

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.figure(figsize=(8,8))
sns.histplot(data=tips['day']) 
# histogram is a simple bar graph like plotting 
# here it is plotted to display the number of tips given on days of a week
# we observe that most of the tips are given on Saturdays and lowest on Fridays

# %%
sns.histplot(x='day',y='total_bill',data=tips)

# %%
sns.pairplot(tips,hue='sex',diag_kind='hist') 
# hue is specified to plot that aspect in different color
# pairplot displays pairwise relationship 
# each numeric value in dataset is represented across x and y axes
# following plottings help us understand relation between tip and total_bill, size and total_bill, tip and size.

# %%
sns.jointplot(x='tip',y='total_bill',data=tips)
# joint plot is combination of univariate an bivariate graphs
# here we get to know the relation between total_bill and tip (bivariate) 
# also we get to know most given tip amount (univariate)

# %%
sns.jointplot(x='tip',y='total_bill',data=tips,hue='sex')
# adding hue parameter will give differentiation among the mentioned attribute(sex)

# %%
sns.catplot(x = 'size', y = 'total_bill', data = tips)
# catplot gives the plotting in categories, even if the values are continuous(total_bill)
# catplot will show them categorically on axes

# %%
sns.displot(x='size', y='total_bill',data=tips)  
# displot helps in visualizing univariate or bivariate distribution of data 
# following example showa bivariate graph which shows how total_bill is distributed as per size of group
# we observe that most of the bill amount is between 10 to 20 if group size is 2 
# for size 1 none of the bill amount is greater than 12

# %%
tips_hm = tips.corr()
print(tips_hm)
plt.figure(figsize=(8,8))
sns.heatmap(tips_hm, cmap="Blues")
# using heatmaps we get to know how the attributes are correlated 
# here we can see total_bill and tip are slightly more correlated as compared tip and size
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
plt.figure(figsize=(8,8))
tips_hm1 = tips.pivot_table(index='day', columns='sex', values='total_bill')
sns.heatmap(tips_hm1, cmap='Blues')
# using this plot we get to know on what day who has greater total_bill
# on sundays male visitors have highest bill while on fridays female visitors have lease bill amount

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
LabelEncoder_X= LabelEncoder()
tips['sex']= LabelEncoder_X.fit_transform(tips['sex'])
tips['day']= LabelEncoder_X.fit_transform(tips['day'])
tips['time']= LabelEncoder_X.fit_transform(tips['time'])
tips['smoker']= LabelEncoder_X.fit_transform(tips['smoker'])

# %%
tips.head()
# Out:
#    total_bill   tip  sex  smoker  day  time  size
# 0       16.99  1.01    0       0    2     0     2
# 1       10.34  1.66    1       0    2     0     3
# 2       21.01  3.50    1       0    2     0     3
# 3       23.68  3.31    1       0    2     0     2
# 4       24.59  3.61    0       0    2     0     4

# %%
# Normalization 
# used min-max normalization as the output will be [0,1] as required by heatmaps
# normalizing all encoded values and total_bill and tip

from sklearn.preprocessing import MinMaxScaler
scaling = MinMaxScaler()
norm_values = scaling.fit_transform(tips[['total_bill', 'tip','sex','smoker','day','time']])

print(norm_values)
tips['total_bill'] = norm_values[:,0]
tips['tip'] = norm_values[:,1]
tips['sex'] = norm_values[:,2]
tips['smoker'] = norm_values[:,3]
tips['day'] = norm_values[:,4]
tips['time'] = norm_values[:,5]

tips_hm = tips.corr()
plt.figure(figsize=(8,8))
sns.heatmap(tips_hm, cmap="Blues")
# Out:
# [[0.29157939 0.00111111 0.         0.         0.66666667 0.        ]
#  [0.1522832  0.07333333 1.         0.         0.66666667 0.        ]
#  [0.3757855  0.27777778 1.         0.         0.66666667 0.        ]
#  ...
#  [0.41055718 0.11111111 1.         1.         0.33333333 0.        ]
#  [0.30896523 0.08333333 1.         0.         0.33333333 0.        ]
#  [0.32907415 0.22222222 0.         0.         1.         0.        ]]

# %%
# from the above plot we can conclude that size and total_bill are highly correlated  
# tip and size are second highly correlated
