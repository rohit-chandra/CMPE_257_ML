# %% [markdown]
# ### Part 1: NLP

# %% [markdown]
# Solve spam sms detection problem using Gensim word2vec. You can use algorithm of your choice to train and evaluate the model.

# %%
import pandas as pd
import numpy as np 
import gensim 
from sklearn.model_selection import  train_test_split
import nltk 
from nltk.corpus import stopwords
import re

from google.colab import files
files.upload()

data = pd.read_csv("spam.csv", encoding='latin-1')
data = data.iloc[:,:2]

data.columns = ["label","text"]
data
# Out:
#      <input type="file" id="files-5c5bcec5-da3f-491a-b71a-4e292aeafe33" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5c5bcec5-da3f-491a-b71a-4e292aeafe33">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
#      label                                               text
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham              Will Ì_ b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
X = data.iloc[:,1]
Y = data.iloc[:,0]

Y = Y.map({"ham":0, "spam":1})  # to perform binary classification 
Y = np.array(Y).reshape(-1,1)
Y
# Out:
# array([[0],
#        [0],
#        [1],
#        ...,
#        [0],
#        [0],
#        [0]])

# %%
nltk.download("stopwords")
words = [text.split() for text in X]
stop_words = set(stopwords.words('english'))

text = X.copy()
text = text.str.lower().str.split()
#print(text)

for index, stop in enumerate(stop_words):
  text = text.apply(lambda x : [word for word in x if word not in stop])

#print(text)
texts = text.to_list()
data['stopped'] = texts
data

data['cleaned'] = [', '.join(map(str, x)) for x in data['stopped']]
#print(data['cleaned'])

for i,msg in enumerate(data['cleaned']):
  data['cleaned'].iloc[i] = msg.replace(",","")
  #print(msg)

#data
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
X = [line for line in data['cleaned']]
Y = np.array(Y).reshape(-1,1)

#X

# %%
x_train, x_test, y_train, y_test =  train_test_split(X, Y, test_size=0.2)
print(x_train)
#print(y_train)
words = [line.split() for line in x_train]
print(words)
#print(len(y_test))
w2vec = gensim.models.Word2Vec(size=200, min_count=1, window=3,workers=8)
w2vec.build_vocab(words)
# Out:
# ['sure mean \\get', 'warner village 83118 colin farrell swat wkend @warner village & get 1 free med. popcorn!just show msg+ticket@kiosk.valid 4-7/12. t&c @kiosk. reply sony 4 mre film offers', 'lets make saturday monday per convenience.', 'eat shit wait monkey face bitch.......... asshole..................', 's:)s.nervous &lt;#&gt; :)', "i'm town i'll take mrt later.", 'ok lor...', 'urgent! call 09066350750 landline. complimentary 4* ibiza holiday 10000 cash await collection sae t&cs po box 434 sk3 8wp 150 ppm 18+', "balance å£500. next question is: sang 'uptown girl' 80's ? 2 answer txt answer 83600. good luck!", "sweet may may go 4u meet carlos gauge patty's interest", 'not?', 'anything specific regards jaklin idk fuck', "yeah should. think gt atm register. sure there's anyway help let know. sure ready.", "let know details fri find cos i'm tom fri. mentionned chinese. thanks", 'peteis phone still? jenny college leanne.what now?:)', "sorry i'll call later meeting", 'jordan got voted last nite!', 'sounds good. fingers . makes difficult type', "piggy awake? still sleeping. i'm going 4 lunch now...", 'get ready &lt;#&gt; inches pleasure...', 'change again... one next escalator...', "think i've fixed send test message?", 'hi please get &lt;#&gt; dollar loan you. i.ll pay back mid february. pls.', 'let heart compass mind map soul guide never loose world....gnun - sent via way2sms.com', 'dad says hurry hell', 'were/are free give. otherwise nalla adi entey nattil kittum', 'december only! mobile 11mths+? entitled update latest colour camera mobile free! call mobile update free 08002986906', 'say bold torch later. one torch 2bold?', 'mobile 10 mths? update latest camera/video phones free. keep number get extra free mins/texts. text yes call', 'download fring app?', 'k bored come home..', "sorry man account's dry would want trade back half buy shit credit card", 'beautiful truth gravity.. read carefully: \\our heart feels light someone it.. feels heavy someone leaves it..\\" goodmorning"', 'free day finish 6 mon thurs...', '[\x89û_] anyway many good evenings u!', 'december only! mobile 11mths+? entitled update latest colour camera mobile free! call mobile update free 08002986906', "who's say drugdealer", '100 dating service cal;l 09064012103 box334sk38ch', "telling dat i'll leaving 4 shanghai 21st instead we'll haf time 2 meet cya...", 'alrite', 'hello boytoy ... geeee miss already woke up. wish bed me cuddling me. love ...', 'thank you winner notified sms. good luck! future marketing reply stop 84122 customer services 08450542832', 'well like actually called someone punto. woulda worse.', "stop story. i've told i've returned saying order it.", 'lol well without me. big sale together.', 'customer place call', 'congrats! 1 year special cinema pass 2 yours. call 09061209465 now! suprman v matrix3 starwars3 etc 4 free! bx420-ip4-5we. 150pm. dont miss out!', 'apparently bffs carly quick', 'no. 1 nokia tone 4 mob every week! txt nok 87021. 1st tone free ! get txtin tell friends. 150p/tone. 16 reply hl 4info', 'look fuckin time. fuck think', 'stop wondering \\wow ever going stop tm\'ing ?!\\" tm whenever want mine ... *laughs*"', "went attend another two rounds today..but still did't reach home..", "plz note: anyone calling mobile co. &amp; asks type # &lt;#&gt; # &lt;#&gt; . so. disconnect callcoz iz attempt 'terrorist' make sim card no. itz confirmd nokia motorola verified cnn ibn.", '&lt;decimal&gt; common car better buy china asia. find less expensive. i.ll holla', 'reminder: downloaded content already paid for. goto http://doit. mymoby. tv/ collect content.', "lol that's different. go trying find every real life photo ever took.", 'screaming means shouting..', 'huh means computational science... like dat one push there...', 'much better thanks lol', 'let know got money carlos make call', 'probs hon! doinat mo?', "way school. pls send ashley's number", "yeah i'll try scrounge something", 'que pases buen tiempo something like', "i'm okay. ...
# [['sure', 'mean', '\\get'], ['warner', 'village', '83118', 'colin', 'farrell', 'swat', 'wkend', '@warner', 'village', '&', 'get', '1', 'free', 'med.', 'popcorn!just', 'show', 'msg+ticket@kiosk.valid', '4-7/12.', 't&c', '@kiosk.', 'reply', 'sony', '4', 'mre', 'film', 'offers'], ['lets', 'make', 'saturday', 'monday', 'per', 'convenience.'], ['eat', 'shit', 'wait', 'monkey', 'face', 'bitch..........', 'asshole..................'], ['s:)s.nervous', '&lt;#&gt;', ':)'], ["i'm", 'town', "i'll", 'take', 'mrt', 'later.'], ['ok', 'lor...'], ['urgent!', 'call', '09066350750', 'landline.', 'complimentary', '4*', 'ibiza', 'holiday', '10000', 'cash', 'await', 'collection', 'sae', 't&cs', 'po', 'box', '434', 'sk3', '8wp', '150', 'ppm', '18+'], ['balance', 'å£500.', 'next', 'question', 'is:', 'sang', "'uptown", "girl'", "80's", '?', '2', 'answer', 'txt', 'answer', '83600.', 'good', 'luck!'], ['sweet', 'may', 'may', 'go', '4u', 'meet', 'carlos', 'gauge', "patty's", 'interest'], ['not?'], ['anything', 'specific', 'regards', 'jaklin', 'idk', 'fuck'], ['yeah', 'should.', 'think', 'gt', 'atm', 'register.', 'sure', "there's", 'anyway', 'help', 'let', 'know.', 'sure', 'ready.'], ['let', 'know', 'details', 'fri', 'find', 'cos', "i'm", 'tom', 'fri.', 'mentionned', 'chinese.', 'thanks'], ['peteis', 'phone', 'still?', 'jenny', 'college', 'leanne.what', 'now?:)'], ['sorry', "i'll", 'call', 'later', 'meeting'], ['jordan', 'got', 'voted', 'last', 'nite!'], ['sounds', 'good.', 'fingers', '.', 'makes', 'difficult', 'type'], ['piggy', 'awake?', 'still', 'sleeping.', "i'm", 'going', '4', 'lunch', 'now...'], ['get', 'ready', '&lt;#&gt;', 'inches', 'pleasure...'], ['change', 'again...', 'one', 'next', 'escalator...'], ['think', "i've", 'fixed', 'send', 'test', 'message?'], ['hi', 'please', 'get', '&lt;#&gt;', 'dollar', 'loan', 'you.', 'i.ll', 'pay', 'back', 'mid', 'february.', 'pls.'], ['let', 'heart', 'compass', 'mind', 'map', 'soul', 'guide', 'never', 'loose', 'world....gnun', '-', 'sent', 'via', 'way2sms.com'], ['dad', 'says', 'hurry', 'hell'], ['were/are', 'free', 'give.', 'otherwise', 'nalla', 'adi', 'entey', 'nattil', 'kittum'], ['december', 'only!', 'mobile', '11mths+?', 'entitled', 'update', 'latest', 'colour', 'camera', 'mobile', 'free!', 'call', 'mobile', 'update', 'free', '08002986906'], ['say', 'bold', 'torch', 'later.', 'one', 'torch', '2bold?'], ['mobile', '10', 'mths?', 'update', 'latest', 'camera/video', 'phones', 'free.', 'keep', 'number', 'get', 'extra', 'free', 'mins/texts.', 'text', 'yes', 'call'], ['download', 'fring', 'app?'], ['k', 'bored', 'come', 'home..'], ['sorry', 'man', "account's", 'dry', 'would', 'want', 'trade', 'back', 'half', 'buy', 'shit', 'credit', 'card'], ['beautiful', 'truth', 'gravity..', 'read', 'carefully:', '\\our', 'heart', 'feels', 'light', 'someone', 'it..', 'feels', 'heavy', 'someone', 'leaves', 'it..\\"', 'goodmorning"'], ['free', 'day', 'finish', '6', 'mon', 'thurs...'], ['[\x89û_]', 'anyway', 'many', 'good', 'evenings', 'u!'], ['december', 'only!', 'mobile', '11mths+?', 'entitled', 'update', 'latest', 'colour', 'camera', 'mobile', 'free!', 'call', 'mobile', 'update', 'free', '08002986906'], ["who's", 'say', 'drugdealer'], ['100', 'dating', 'service', 'cal;l', '09064012103', 'box334sk38ch'], ['telling', 'dat', "i'll", 'leaving', '4', 'shanghai', '21st', 'instead', "we'll", 'haf', 'time', '2', 'meet', 'cya...'], ['alrite'], ['hello', 'boytoy', '...', 'geeee', 'miss', 'already', 'woke', 'up.', 'wish', 'bed', 'me', 'cuddling', 'me.', 'love', '...'], ['thank', 'you', 'winner', 'notified', 'sms.', 'good', 'luck!', 'future', 'marketing', 'reply', 'stop', '84122', 'customer', 'services', '08450542832'], ['well', 'like', 'actually', 'called', 'someone', 'punto.', 'woulda', 'worse.'], ['stop', 'story.', "i've", 'told', "i've", 'returned', 'saying', 'order', 'it.'], ['lol', 'well', 'without', 'me.', 'big', 'sale', 'together.'], ['customer', 'place', 'call'], ['congrats!', '1', 'year', 'special', 'cinema', 'pass', '2', 'your ...

# %%
keys = w2vec.wv.vocab.keys()
print(keys)
vocab_size = len(keys)
print("Vocab size", vocab_size)

w2vec.train(words,total_examples=len(words),epochs=30)
# Out:
# dict_keys(['sure', 'mean', '\\get', 'warner', 'village', '83118', 'colin', 'farrell', 'swat', 'wkend', '@warner', '&', 'get', '1', 'free', 'med.', 'popcorn!just', 'show', 'msg+ticket@kiosk.valid', '4-7/12.', 't&c', '@kiosk.', 'reply', 'sony', '4', 'mre', 'film', 'offers', 'lets', 'make', 'saturday', 'monday', 'per', 'convenience.', 'eat', 'shit', 'wait', 'monkey', 'face', 'bitch..........', 'asshole..................', 's:)s.nervous', '&lt;#&gt;', ':)', "i'm", 'town', "i'll", 'take', 'mrt', 'later.', 'ok', 'lor...', 'urgent!', 'call', '09066350750', 'landline.', 'complimentary', '4*', 'ibiza', 'holiday', '10000', 'cash', 'await', 'collection', 'sae', 't&cs', 'po', 'box', '434', 'sk3', '8wp', '150', 'ppm', '18+', 'balance', 'å£500.', 'next', 'question', 'is:', 'sang', "'uptown", "girl'", "80's", '?', '2', 'answer', 'txt', '83600.', 'good', 'luck!', 'sweet', 'may', 'go', '4u', 'meet', 'carlos', 'gauge', "patty's", 'interest', 'not?', 'anything', 'specific', 'regards', 'jaklin', 'idk', 'fuck', 'yeah', 'should.', 'think', 'gt', 'atm', 'register.', "there's", 'anyway', 'help', 'let', 'know.', 'ready.', 'know', 'details', 'fri', 'find', 'cos', 'tom', 'fri.', 'mentionned', 'chinese.', 'thanks', 'peteis', 'phone', 'still?', 'jenny', 'college', 'leanne.what', 'now?:)', 'sorry', 'later', 'meeting', 'jordan', 'got', 'voted', 'last', 'nite!', 'sounds', 'good.', 'fingers', '.', 'makes', 'difficult', 'type', 'piggy', 'awake?', 'still', 'sleeping.', 'going', 'lunch', 'now...', 'ready', 'inches', 'pleasure...', 'change', 'again...', 'one', 'escalator...', "i've", 'fixed', 'send', 'test', 'message?', 'hi', 'please', 'dollar', 'loan', 'you.', 'i.ll', 'pay', 'back', 'mid', 'february.', 'pls.', 'heart', 'compass', 'mind', 'map', 'soul', 'guide', 'never', 'loose', 'world....gnun', '-', 'sent', 'via', 'way2sms.com', 'dad', 'says', 'hurry', 'hell', 'were/are', 'give.', 'otherwise', 'nalla', 'adi', 'entey', 'nattil', 'kittum', 'december', 'only!', 'mobile', '11mths+?', 'entitled', 'update', 'latest', 'colour', 'camera', 'free!', '08002986906', 'say', 'bold', 'torch', '2bold?', '10', 'mths?', 'camera/video', 'phones', 'free.', 'keep', 'number', 'extra', 'mins/texts.', 'text', 'yes', 'download', 'fring', 'app?', 'k', 'bored', 'come', 'home..', 'man', "account's", 'dry', 'would', 'want', 'trade', 'half', 'buy', 'credit', 'card', 'beautiful', 'truth', 'gravity..', 'read', 'carefully:', '\\our', 'feels', 'light', 'someone', 'it..', 'heavy', 'leaves', 'it..\\"', 'goodmorning"', 'day', 'finish', '6', 'mon', 'thurs...', '[\x89û_]', 'many', 'evenings', 'u!', "who's", 'drugdealer', '100', 'dating', 'service', 'cal;l', '09064012103', 'box334sk38ch', 'telling', 'dat', 'leaving', 'shanghai', '21st', 'instead', "we'll", 'haf', 'time', 'cya...', 'alrite', 'hello', 'boytoy', '...', 'geeee', 'miss', 'already', 'woke', 'up.', 'wish', 'bed', 'me', 'cuddling', 'me.', 'love', 'thank', 'you', 'winner', 'notified', 'sms.', 'future', 'marketing', 'stop', '84122', 'customer', 'services', '08450542832', 'well', 'like', 'actually', 'called', 'punto.', 'woulda', 'worse.', 'story.', 'told', 'returned', 'saying', 'order', 'it.', 'lol', 'without', 'big', 'sale', 'together.', 'place', 'congrats!', 'year', 'special', 'cinema', 'pass', 'yours.', '09061209465', 'now!', 'suprman', 'v', 'matrix3', 'starwars3', 'etc', 'bx420-ip4-5we.', '150pm.', 'dont', 'out!', 'apparently', 'bffs', 'carly', 'quick', 'no.', 'nokia', 'tone', 'mob', 'every', 'week!', 'nok', '87021.', '1st', '!', 'txtin', 'tell', 'friends.', '150p/tone.', '16', 'hl', '4info', 'look', 'fuckin', 'time.', 'wondering', '\\wow', 'ever', "tm'ing", '?!\\"', 'tm', 'whenever', 'mine', '*laughs*"', 'went', 'attend', 'another', 'two', 'rounds', 'today..but', "did't", 'reach', 'plz', 'note:', 'anyone', 'calling', 'co.', '&amp;', 'asks', '#', 'so.', 'disconnect', 'callcoz', 'iz', 'attempt', "'terrorist'", 'sim', 'itz', 'confirmd', 'motorola', 'verified', 'cnn', 'ibn.', '&lt;decimal&gt;', 'common', 'car', 'better', 'china', 'asia.', 'les ...
# Vocab size 11151
# (1183298, 1232370)

# %%
w2vec.wv.most_similar("role")
# Out:
# [('people.', 0.9993878602981567),
#  ('rather', 0.9993140697479248),
#  ('cat', 0.9992601871490479),
#  ('rock', 0.99924236536026),
#  ('girls', 0.9992402791976929),
#  ('damn', 0.9992326498031616),
#  ('meant', 0.9992159605026245),
#  ('right.', 0.9992154240608215),
#  ('sister', 0.999212384223938),
#  ('later?\\""', 0.9991198778152466)]

# %%
from keras.preprocessing.text import Tokenizer
tokenizer=Tokenizer()

tokenizer.fit_on_texts(x_train)
vocab_size = len(tokenizer.word_index) + 1
print("Total words", vocab_size)

from keras.preprocessing.sequence import pad_sequences
xtrain = pad_sequences(tokenizer.texts_to_sequences(x_train), maxlen=300)
xtest = pad_sequences(tokenizer.texts_to_sequences(x_test), maxlen=300)

print(xtrain)
# Out:
# Total words 7897
# [[   0    0    0 ...   98  518    4]
#  [   0    0    0 ... 3721  817 1130]
#  [   0    0    0 ...  818  164 3722]
#  ...
#  [   0    0    0 ...  788 7896   38]
#  [   0    0    0 ...    7    6  321]
#  [   0    0    0 ...   28   36  144]]

# %%
from sklearn.metrics import accuracy_score
from sklearn import tree

model = tree.DecisionTreeClassifier()
model.fit(xtrain,y_train)
prediction = model.predict(xtest)
accuracy_score(y_test, prediction)
# Out:
# 0.9085201793721973

# %% [markdown]
# ### Part 2: Content Based Recommender

# %% [markdown]
# Build a system that recommends movies that are similar to a particular movie

# %%
# Load 'overview' feature in metadata dataset

# %%
from google.colab import files
files.upload()

import pandas as pd

movie_data = pd.read_csv("movies_metadata.csv", low_memory=False)
movie_data.shape
# Out:
#      <input type="file" id="files-986bdea6-d069-41de-a561-9accad575a46" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-986bdea6-d069-41de-a561-9accad575a46">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# (45466, 24)

# %%
# Use your judgement to preprocess data

# %%
movie_data = movie_data.dropna()        #dropping all rows where atlease one value is NA....I dropped all rows with NA as I wanted a smaller subset of data because I was getting memmory error
movie_data.shape
# Out:
# (693, 24)

# %%
# Construct TF-IDF matrix

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tf = TfidfVectorizer(ngram_range=(1, 3),min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(movie_data['overview'])
tfidf_matrix.shape
# Out:
# (693, 46596)

# %%
# Compute cosine similarity score between movies

# %%
from sklearn.metrics.pairwise import linear_kernel

cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

movie_data = movie_data.reset_index()
print(movie_data)
#indices = movie_data['index'].toint()
titles = movie_data['title']
print(titles)
# finding indices of every title
movies = pd.Series(movie_data.index, index=titles)
print("movies ", movies)
# Out:
#      index  adult  ... vote_average vote_count
# 0        9  FALSE  ...          6.6     1194.0
# 1       68  FALSE  ...          7.0      513.0
# 2       69  FALSE  ...          6.9     1644.0
# 3      153  FALSE  ...          6.8       28.0
# 4      178  FALSE  ...          5.2      153.0
# ..     ...    ...  ...          ...        ...
# 688  44274  FALSE  ...          6.7     1675.0
# 689  44674  FALSE  ...          6.0       35.0
# 690  44821  FALSE  ...          6.0      144.0
# 691  44842  FALSE  ...          6.2     1440.0
# 692  45029  FALSE  ...          6.8        5.0
#
# [693 rows x 25 columns]
# 0                                    GoldenEye
# 1                                       Friday
# 2                          From Dusk Till Dawn
# 3                             Blue in the Face
# 4      Mighty Morphin Power Rangers: The Movie
#                         ...
# 688             War for the Planet of the Apes
# 689                Goon: Last of the Enforcers
# 690              Pokémon: Spell of the Unknown
# 691              Transformers: The Last Knight
# 692                          Bon Cop Bad Cop 2
# Name: title, Length: 693, dtype: object
# movies  title
# GoldenEye                                    0
# Friday                                       1
# From Dusk Till Dawn                          2
# Blue in the Face                             3
# Mighty Morphin Power Rangers: The Movie      4
#                                           ...
# War for the Planet of the Apes             688
# Goon: Last of the Enforcers                689
# Pokémon: Spell of the Unknown              690
# Transformers: The Last Knight              691
# Bon Cop Bad Cop 2                          692
# Length: 693, dtype: int64

# %%
# Take movie title as input and output 10 most similar movies

# %%
movie = input("Write a movie name to find 10 similar movies : ")

idx = movies[movie]
print("Index ",idx)
sim_scores = list(enumerate(cosine_sim[idx]))

sim_scores = sorted(sim_scores, key=lambda x:x[1], reverse=True)
sim_scores = sim_scores[1:11]
movie_indices = [i[0] for i in sim_scores]

print("Recommended Movies")

output = []
count = 1
for item in titles.iloc[movie_indices]:
  output.append(item)
  print(count," -> ",item)
  count += 1
# Out:
# Write a movie name to find 10 similar movies : Friday
# Index  1
# Recommended Movies
# 1  ->  Escape from L.A.
# 2  ->  Cross
# 3  ->  30 Days of Night: Dark Days
# 4  ->  Constantine
# 5  ->  Blade Runner
# 6  ->  Ouija: Origin of Evil
# 7  ->  Sharknado
# 8  ->  Terminator Genisys
# 9  ->  Klown
# 10  ->  Before Sunset
